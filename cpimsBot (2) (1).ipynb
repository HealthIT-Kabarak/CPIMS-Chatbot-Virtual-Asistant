# %% [markdown]
# ## Section 1.1: Import necessary libraries

# %%
import pandas as pd
import re
import nltk

# %% [markdown]
# #### Section 1.1.0: creating list of files text to combined

# %%
filenames = ['whatsappchat-Bungoma.txt', 'whatsappchat-Msa.txt', 'whatsappchat-Nairobi.txt', 'whatsappchat-Wajiri.txt', 'whatsappchat-institution.txt']

# %% [markdown]
# #### Section 1.1.1: Creating a function to handle the logs to do custom error handling

# %%
# defining a function to handle bad lines
def handle_bad_line(line):
    with open('bad_lines.log', 'a') as f:
        f.write(str(line) + '\n')

# %% [markdown]
# #### Section 1.1.2: Looping through filename and passing handle_bad_line function to the filenames

# %%
# create an empty list to store the data frames
dfs = []

# loop through the filenames and read in the files
for filename in filenames:
    try:
        # read in the file and handle any bad lines
        df = pd.read_csv(filename, delimiter='\t', on_bad_lines=handle_bad_line, engine='python')
        dfs.append(df)
    except Exception as e:
        print(f"Error reading {filename}: {str(e)}")

# %%
#### Section 1.1.3: Concatenating the dataframes into one dataframe

# %%
# concatenate the data frames into a single data frame
combined_data = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# #### Section 1.1.4: Removing the missing values

# %%
# fill in any missing values
combined_data = combined_data.fillna('')

# %% [markdown]
# #### Section 1.1.1: Combining the multiple text files into one file

# %%
combined_data.to_csv("combined-cpims-dataset.csv", index=False, sep="\t")

# %% [markdown]
# ## Section 1.2: Loading our datasets from the combined whatsapp text file

# %%
whatsapp_data = pd.read_csv('combined-cpims-dataset.csv', sep='\r\n', header=None, names=['text'], engine='python')

# %% [markdown]
# ## Section 1.3: Visualizing our datasets

# %%
whatsapp_data
# Out:
#                                                    text
# 0     21/09/2017, 9:20 pm - Messages and calls are e...
# 1     "21/09/2017, 9:08 pm - +254 708 778478 created...
# 2       21/09/2017, 9:20 pm - +254 708 778478 added you
# 3     21/09/2017, 9:23 pm - Joshua Mbai: Congratulat...
# 4     21/09/2017, 9:23 pm - Joshua Mbai: Thanks for ...
# ...                                                 ...
# 6460  24/01/2023, 2:15 pm - Margaret Kagwiria turned...
# 6461  24/01/2023, 5:00 pm - Margaret Kagwiria: This ...
# 6462  24/01/2023, 5:02 pm - Margaret Kagwiria: One o...
# 6463  24/01/2023, 5:29 pm - Gertrude Nyangweso: Plea...
# 6464                25/01/2023, 11:59 am - Lilian: Done
#
# [6465 rows x 1 columns]

# %% [markdown]
# ## Section 1.4: Data Cleansing
#  - Removing urls from the text
#  - Removing the phone numers
#  - Removing the emojis
#
# #### We should the cleanse our dataset before building our bot

# %%
## Removing the urls from the datasets
whatsapp_data['text'] = whatsapp_data['text'].apply(lambda x: re.sub(r'http\S+','', x))

# %%
## Removing the phone numbers from the datasets
whatsapp_data['text'] = whatsapp_data['text'].apply(lambda x: re.sub(r'\d{10}','', x))

# %%
## Removing the emojis from the text
whatsapp_data['text'] = whatsapp_data['text'].apply(lambda x: re.sub(r'[\U0001F600-\U0001F64F]', '', x))

# %% [markdown]
# ## Section 1.5: Downloading the wordnet and punkt

# %%
# this is a nltk module that is used to find the meanings of words or synonyms 
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gideo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# this is a nltk module that is used to divide text into sentences
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gideo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Section 1.6: Tokenization of the text

# %%
## Tokenization is the converting of text into a list of words
## Here, we are 
whatsapp_data['text'] = whatsapp_data['text'].apply(lambda x: nltk.word_tokenize(x.lower()))

# %% [markdown]
# ## Section 1.7: Downloading stopwords

# %%
## Downloading Stopwords
## Stopwords are common words which you do not want to use to describe the topic of your content eg. a, and
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gideo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ##  Section 1.8: Importing stopwords

# %%
from nltk.corpus import stopwords

## Setting stop words for Englishhttps://www.datasciencelearner.com/typeerror-module-object-is-not-callable-fix/
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ## Section 1.9: Removing the stopwords

# %%
whatsapp_data['text'] = whatsapp_data['text'].apply(lambda x: [word for word in x if word not in stop_words])

# %% [markdown]
# ## Section 2.0: Removing the special characters from whatsapp dataset

# %%
whatsapp_data['text'] = whatsapp_data['text'].apply(lambda x: [re.sub(r'[^a-zA-Z0-9]', '', word) for word in x])

# %% [markdown]
# ## Section 2.1: Removing the empty strings from whatsapp datasets

# %%
whatsapp_data['text'] = whatsapp_data['text'].apply(lambda x: [word for word in x if len(word) > 0])

# %% [markdown]
# ## Section 2.2: Saving the cleaned whatsapp_data as a text file

# %%
whatsapp_data.to_csv('cleaned_whatsapp_data.txt', index=False, header=None, sep='\n')

# %%
# Open input and output files
with open("cleaned_whatsapp_data.txt", "r") as input_file, open("output_file.txt", "w") as output_file:
    # Read input file as a single string
    document = input_file.read()
    
    # Remove "pm" from document
    cleaned_document = document.replace("pm", "")
    
    # Write modified document to output file
    output_file.write(cleaned_document)

# %%
import re

# Open input and output files
with open("cleaned_whatsapp_data.txt", "r") as input_file, open("output_file.txt", "w") as output_file:
    # Read input file as a single string
    document = input_file.read()
    
    # Remove "21092017" from document
    cleaned_document = re.sub(r'\d{8}', '', document)
    
    # Write modified document to output file
    output_file.write(cleaned_document)

# %%
cleaned_document
# Out:
# "['', '920', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '105', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '647', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '135', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '344', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn']\n['', '908', 'pm', '254', '708', '778478', 'created', 'group', 'bungoma', 'cpims', 'group']\n['', '920', 'pm', '254', '708', '778478', 'added']\n['', '923', 'pm', 'joshua', 'mbai', 'congratulations', 'bungoma', 'team']\n['', '923', 'pm', 'joshua', 'mbai', 'thanks', 'add']\n['', '924', 'pm', 'ngetich', 'ericson', 'welcome', 'bwana', 'mbai']\n['', '925', 'pm', 'ngetich', 'ericson', 'changed', 'group', 's', 'icon']\n['', '930', 'pm', '254', '708', '778478', 'added', '254', '700', '751891']\n['', '949', 'pm', '254', '708', '778478', 'removed', 'ngetich', 'ericson']\n['', '949', 'pm', '254', '708', '778478', 'added', 'ngetich', 'ericson']\n['', '951', 'pm', 'ngetich', 'ericson', 'mapema', 'sana', 'bwana', 'adm']\n['', '954', 'pm', '254', '707', '509011', 'poa']\n['', '306', 'derrick', 'cheburet', 'congratulations', 'guys', 'let', 'us', 'embark', 'making', 'child', 'protection', 'cpims', 'success']\n['', '702', 'elizabeth', 'nanjala', 'thanks']\n['', '948', '254', '708', '778478', 'added', 'keya', 'mark', 'dcs', 'kisumu']\n['', '948', '254', '708', '778478', 'added', '254', '708', '402827']\n['', '948', '254', '708', '778478', 'added', 'christine', 'onganyo']\n['', '948', '254', '708', '778478', 'added', 'beatrice', 'oguda']\n['', '948', '254', '708', '778478', 'added', 'ogindo', 'peter']\n['', '948', '254', '708', '778478', 'added', '254', '728', '445000']\n['', '948', '254', '708', '778478', 'added', '254', '718', '781040']\n['', '948', '254', '708', '778478', 'added', '254', '722', '251705']\n['', '948', '254', '708', '778478', 'added', '254', '707', '377970']\n['', '947', '254', '708', '778478', 'changed', 'group', 's', 'icon']\n['', '922', 'hellen', 'mosoti', 'media', 'omitted']\n['could', 'please', 'set', 'profile', 'picture']\n['', '947', 'keya', 'mark', 'dcs', 'kisumu', 'karibu', 'sana', 'team', 'bungoma', 'vituvichenjanga']\n['', '1003', '254', '798', '527587', 'thnx', 'exposure', 'cpims', 'group', 'endelea', 'kupima', 'counties']\n['', '1004', '254', '707', '509011', 'poa']\n['', '1049', '254', '711', '996986', 'good', 'job', 'good', 'pple']\n['', '1130', 'elizabeth', 'nanjala', 'added', 'david', 'magogo']\n['', '1130', 'elizabeth', 'nanjala', 'added', '254', '723', '337699']\n['', '1141', 'elizabeth', 'nanjala', 'added', 'scco', 'juja', 'dcs', 'emmanuel', 'mbae']\n['', '1142', 'elizabeth', 'nanjala', 'added', 'nicholas', 'sdo2']\n['', '1221', 'pm', 'david', 'magogo', 'welcome']\n['', '916', 'pm', 'elizabeth', 'nanjala', 'changed', 'group', 's', 'icon']\n['', '918', 'pm', 'elizabeth', 'nanjala', 'changed', 'group', 's', 'icon']\n['', '332', 'pm', 'nicholas', 'sdo2', 'thanx']\n['', '421', 'pm', 'elizabeth', 'nanjala', 'team', 'webuye', 'wamefika', 'salama', 'thank', 'god']\n['', '536', 'pm', '254', '708', '778478', 'team', 'bungoma', 'west', 'tumefika', 'poa']\n['', '738', 'pm', 'elizabeth', 'nanjala']\n['', '738', 'pm', 'elizabeth', 'nanjala', 'asante', 'sana', 'bwana', 'mark', 'tutachenjanga', 'tata', 'navigation', 'na', 'cpims']\n['', '812', 'pm', 'david', 'magogo', 'arrived']\n['', '843', 'pm', 'ngetich', 'ericson', 'team', 'bungoma', 'south', 'pia', 'salama']\n['', '846', 'pm', '254', '710', '118775', 'amen']\n['', '853', 'pm', 'scco', 'juja', 'dcs', 'emmanuel', 'mbae', 'nrb', 'pap', 'thanks', 'guys', 'let', 'us', ' ...

# %%
import re

# Open input and output files
with open("cleaned_whatsapp_data.txt", "r") as input_file, open("output_file.txt", "w") as output_file:
    # Read input file as a single string
    document = input_file.read()
    
    # Remove numbers from document
    cleaned_document = re.sub(r'\d+', '', document)
    
    # Write modified document to output file
    output_file.write(cleaned_document)

# %%
cleaned_document
# Out:
# "['', '', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn', '', '', 'pm', 'messages', 'calls', 'endtoend', 'encrypted', 'one', 'outside', 'chat', 'even', 'whatsapp', 'read', 'listen', 'tap', 'learn']\n['', '', 'pm', '', '', '', 'created', 'group', 'bungoma', 'cpims', 'group']\n['', '', 'pm', '', '', '', 'added']\n['', '', 'pm', 'joshua', 'mbai', 'congratulations', 'bungoma', 'team']\n['', '', 'pm', 'joshua', 'mbai', 'thanks', 'add']\n['', '', 'pm', 'ngetich', 'ericson', 'welcome', 'bwana', 'mbai']\n['', '', 'pm', 'ngetich', 'ericson', 'changed', 'group', 's', 'icon']\n['', '', 'pm', '', '', '', 'added', '', '', '']\n['', '', 'pm', '', '', '', 'removed', 'ngetich', 'ericson']\n['', '', 'pm', '', '', '', 'added', 'ngetich', 'ericson']\n['', '', 'pm', 'ngetich', 'ericson', 'mapema', 'sana', 'bwana', 'adm']\n['', '', 'pm', '', '', '', 'poa']\n['', '', 'derrick', 'cheburet', 'congratulations', 'guys', 'let', 'us', 'embark', 'making', 'child', 'protection', 'cpims', 'success']\n['', '', 'elizabeth', 'nanjala', 'thanks']\n['', '', '', '', '', 'added', 'keya', 'mark', 'dcs', 'kisumu']\n['', '', '', '', '', 'added', '', '', '']\n['', '', '', '', '', 'added', 'christine', 'onganyo']\n['', '', '', '', '', 'added', 'beatrice', 'oguda']\n['', '', '', '', '', 'added', 'ogindo', 'peter']\n['', '', '', '', '', 'added', '', '', '']\n['', '', '', '', '', 'added', '', '', '']\n['', '', '', '', '', 'added', '', '', '']\n['', '', '', '', '', 'added', '', '', '']\n['', '', '', '', '', 'changed', 'group', 's', 'icon']\n['', '', 'hellen', 'mosoti', 'media', 'omitted']\n['could', 'please', 'set', 'profile', 'picture']\n['', '', 'keya', 'mark', 'dcs', 'kisumu', 'karibu', 'sana', 'team', 'bungoma', 'vituvichenjanga']\n['', '', '', '', '', 'thnx', 'exposure', 'cpims', 'group', 'endelea', 'kupima', 'counties']\n['', '', '', '', '', 'poa']\n['', '', '', '', '', 'good', 'job', 'good', 'pple']\n['', '', 'elizabeth', 'nanjala', 'added', 'david', 'magogo']\n['', '', 'elizabeth', 'nanjala', 'added', '', '', '']\n['', '', 'elizabeth', 'nanjala', 'added', 'scco', 'juja', 'dcs', 'emmanuel', 'mbae']\n['', '', 'elizabeth', 'nanjala', 'added', 'nicholas', 'sdo']\n['', '', 'pm', 'david', 'magogo', 'welcome']\n['', '', 'pm', 'elizabeth', 'nanjala', 'changed', 'group', 's', 'icon']\n['', '', 'pm', 'elizabeth', 'nanjala', 'changed', 'group', 's', 'icon']\n['', '', 'pm', 'nicholas', 'sdo', 'thanx']\n['', '', 'pm', 'elizabeth', 'nanjala', 'team', 'webuye', 'wamefika', 'salama', 'thank', 'god']\n['', '', 'pm', '', '', '', 'team', 'bungoma', 'west', 'tumefika', 'poa']\n['', '', 'pm', 'elizabeth', 'nanjala']\n['', '', 'pm', 'elizabeth', 'nanjala', 'asante', 'sana', 'bwana', 'mark', 'tutachenjanga', 'tata', 'navigation', 'na', 'cpims']\n['', '', 'pm', 'david', 'magogo', 'arrived']\n['', '', 'pm', 'ngetich', 'ericson', 'team', 'bungoma', 'south', 'pia', 'salama']\n['', '', 'pm', '', '', '', 'amen']\n['', '', 'pm', 'scco', 'juja', 'dcs', 'emmanuel', 'mbae', 'nrb', 'pap', 'thanks', 'guys', 'let', 'us', 'counties', 'group']\n['', '', 'pm', 'elizabeth', 'nanjala']\n['', '', 'pm', 'elizabeth', 'nanjala']\n['', '', 'pm', 'elizabeth', 'nanjala']\n['', '', 'pm', '', '', '']\n['', '', 'pm', '', '', '']\n['', '', '', '', '', 'mbae', 'welcome']\n['', '', 'director', 'judy', 'tuda', 'sau', 'good', 'mornings', 'team', 'bgm', 'glad', 'locked', 'cpims', 'looking', 'forward', 'seeing', 'meet', 'target', 'entering', 'cases', 'test', 'environment', 'month', 'end', 'live', 'system', 'october', 'ama', 'go ...

# %% [markdown]
# ## Section 2.3: Loading the cleaned whatsapp_data text file to convert it to nlu.md

# %%
cleaned_whatsapp_data = pd.read_csv('cleaned_whatsapp_data.txt', sep='\r\n', header=None, names=['text'], engine='python')

#viewing the cleaned dataset
cleaned_whatsapp_data
